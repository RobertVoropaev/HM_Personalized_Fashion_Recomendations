# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

from scipy.sparse import csr_matrix

from tqdm import tqdm
from datetime import datetime, timedelta

import logging
logging.basicConfig(level=logging.INFO)
logging.info("test")
# Out:
# INFO:root:test

# %%
articles = pd.read_csv("../input/articles_proc.csv", dtype={"article_id": str})
customers = pd.read_csv("../input/customers_proc.csv")
transactions_full = pd.read_csv("../input/transactions_full.csv", dtype={"article_id": str})
transactions_train = pd.read_csv("../input/transactions_train.csv", dtype={"article_id": str})
transactions_test = pd.read_csv("../input/transactions_test.csv", dtype={"article_id": str})

# %%
transactions_full["month"] = transactions_full.t_dat.str.split("-").str[1].astype(int)

# %%
data = (
    transactions_full[transactions_full.t_dat >= "2020-01-01"]
        [["month", "article_id"]].drop_duplicates()
        .groupby("month")["article_id"].count()
)
data
# Out:
# month
# 1    30167
# 2    31231
# 3    28764
# 4    23000
# 5    29681
# 6    32309
# 7    30897
# 8    30162
# 9    26252
# Name: article_id, dtype: int64

# %%
articles
# Out:
#         article_id product_type_name  product_group_name  \
# 0       0108775015          Vest top  Garment Upper body
# 1       0108775044          Vest top  Garment Upper body
# 2       0108775051          Vest top  Garment Upper body
# 3       0110065001               Bra           Underwear
# 4       0110065002               Bra           Underwear
# ...            ...               ...                 ...
# 105537  0953450001             Socks      Socks & Tights
# 105538  0953763001          Vest top  Garment Upper body
# 105539  0956217002             Dress   Garment Full body
# 105540  0957375001         Hair clip         Accessories
# 105541  0959461001             Dress   Garment Full body
#
#        graphical_appearance_name colour_group_name  \
# 0                          Solid             Black
# 1                          Solid             White
# 2                         Stripe         Off White
# 3                          Solid             Black
# 4                          Solid             White
# ...                          ...               ...
# 105537           Placement print             Black
# 105538                     Solid             Black
# 105539                     Solid             Black
# 105540                     Solid             Black
# 105541                     Solid         Off White
#
#        perceived_colour_value_name perceived_colour_master_name  \
# 0                             Dark                        Black
# 1                            Light                        White
# 2                      Dusty Light                        White
# 3                             Dark                        Black
# 4                            Light                        White
# ...                            ...                          ...
# 105537                        Dark                        Black
# 105538                        Dark                        Black
# 105539                        Dark                        Black
# 105540                        Dark                        Black
# 105541                 Dusty Light                        White
#
#               index_name index_group_name garment_group_name  \
# 0             Ladieswear       Ladieswear       Jersey Basic
# 1             Ladieswear       Ladieswear       Jersey Basic
# 2             Ladieswear       Ladieswear       Jersey Basic
# 3       Lingeries/Tights       Ladieswear  Under-, Nightwear
# 4       Lingeries/Tights       Ladieswear  Under-, Nightwear
# ...                  ...              ...                ...
# 105537          Menswear         Menswear   Socks and Tights
# 105538        Ladieswear       Ladieswear       Jersey Fancy
# 105539        Ladieswear       Ladieswear       Jersey Fancy
# 105540           Divided          Divided        Accessories
# 105541        Ladieswear       Ladieswear       Jersey Fancy
#
#                                               detail_desc product_code_name  \
# 0                 Jersey top with narrow shoulder straps.             Other
# 1                 Jersey top with narrow shoulder straps.             Other
# 2                 Jersey top with narrow shoulder straps.             Other
# 3       Microfibre T-shirt bra with underwired, moulde...             Other
# 4       Microfibre T-shirt bra with underwired, moulde...             Other
# ...                                                   ...               ...
# 105537  Socks in a fine-knit cotton blend with a small...             Other
# 105538  Loose-fitting sports vest top in ribbed fast-d...             Other
# 105539  Short, A-line dress in jersey with a round nec...             Other
# 105540                           Large plastic hair claw.             Other
# 105541  Calf-length dress in ribbed jersey made from a...             Other
#
#              department_no_name             section_no_name  price_min  \
# 0            1676: Jersey Basic  16: Womens Everyday Basics   0.001339
# 1            1676: Jersey Basic  16: Womens Everyday Basics   0.001424
# 2            1676: Jersey Basic  16: Womens Everyday Basics   0.003237
# 3          1339: Clean Lingerie         61: Womens Lingerie   0.002525
# 4          1339: Clean Lingerie         61: Womens Lingerie   0.004542
# ...                         ...                         ...        ...
# 105537          7188: Socks Bin           26: Men Underwear   0.015305
# 105538             1919: Jersey                     2: H&M+   0.021169
# 105539             1641: Jersey            18: Womens Trend   0.057407
# 105540  3946: Small Accessories     52: Divided Accessories   0.000000
# 105541             1641: Jersey            18: Womens Trend   0.000000
#
#         price_max  price_mean  price_std  sales_channel_1_sum  \
# 0        0.009153    0.008142   0.000652               2485.0
# 1        0.008508    0.008114   0.000735               2101.0
# 2        0.008458    0.004980   0.000544                  1.0
# 3        0.025407    0.020219   0.006844                652.0
# 4        0.025407    0.018205   0.006004                186.0
# ...           ...         ...        ...                  ...
# 105537   0.016932    0.016836   0.000395                  0.0
# 105538   0.022017    0.021908   0.000251                  0.0
# 105539   0.059305    0.059152   0.000493                  0.0
# 105540   0.000000    0.000000   0.000000                  0.0
# 105541   0.000000    0.000000   0.000000                  0.0
#
#         sales_channel_2_sum
# 0                    8356.0
# 1                    5149.0
# 2                     214.0
# 3                     392.0
# 4                     353.0
# ...                     ...
# 105537                 17.0
# 105538                 35.0
# 105539                 21.0
# 105540                  0.0
# 105541                  0.0
#
# [105542 rows x 20 columns]

# %%
plt.figure(figsize=(20, 10))
plt.plot(data["month", map_list)
plt.show()
